# %% [markdown]
# # Crowdsourcing Tutorial
# How to use Snorkel in conjunction with crowdsourcing to create a training set for a sentiment analysis task.
#
# Given
# - Crowdsourced labels account for about half of the training dataset.
# - The crowdsourced labels are fairly accurate
# - They do not cover the entire training dataset
# - They are not available for the test set or during inference
#
# To make up for their lack of training set coverage, we combine crowdsourced labels with heuristic labeling functions to increase the number of training labels. We will use the denoised labels to train a deep learning model which can be applied to new, unseen data to automatically make predictions.

# %% [markdown]
# ## Dataset Details
# This tuturial will use [Weather Sentiment](https://data.world/crowdflower/weather-sentiment) dataset from Figure Eight. The goal is to train a classifier that can label new tweets as expressing either a positive or negative sentiment.
#
# Crowdworkers were asked to label the sentiment of a particular tweet relating to the weather. The catch is that 20 crowdworkers graded each tweet, and in many cases crowdworkers assigned conflicting sentiment labels to the same tweet. This is a common issue when dealing with crowdsourced labeling workloads.
#
# Each crowdworker's labels are treated as coming from a single labeling function (LF). This will allow us to learn a weight for how much to trust the labels from each crowdworker. We will also write a few heuristic labeling functions to cover the data points without crowd labels. Snorkel's ability to build high-quality dataset from multiple noisy labeling signals make it an ideal framework to approach this problem.

# %% [markdown]
# ## Preparation

# %%
import os

if os.path.basename(os.getcwd()) == "snorkel-tutorials":
  os.chdir("./crowdsourcing")

os.getcwd()
# Out:
# '/Users/scottchu/Projects/learning/snorkel-tutorials/crowdsourcing'

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: matplotlib in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (3.5.0)
# Requirement already satisfied: pytorch-transformers in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: textblob in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (0.17.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 1)) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 1)) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 1)) (4.28.2)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: setuptools-scm>=4 in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 1)) (6.3.2)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 1)) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 1)) (3.0.6)
# Requirement already satisfied: numpy>=1.17 in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 1)) (1.19.5)
# Requirement already satisfied: boto3 in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from pytorch-transformers->-r requirements.txt (line 2)) (1.20.21)
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from pytorch-transformers->-r requirements.txt (line 2)) (2.26.0)
# Requirement already satisfied: tqdm in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from pytorch-transformers->-r requirements.txt (line 2)) (4.62.3)
# Requirement already satisfied: sentencepiece in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from pytorch-transformers->-r requirements.txt (line 2)) (0.1.95)
# Requirement already satisfied: sacremoses in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from pytorch-transformers->-r requirements.txt (line 2)) (0.0.46)
# Requirement already satisfied: regex in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from pytorch-transformers->-r requirements.txt (line 2)) (2021.11.10)
# Requirement already satisfied: torch>=1.0.0 in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from pytorch-transformers->-r requirements.txt (line 2)) (1.10.0)
# Requirement already satisfied: nltk>=3.1 in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from textblob->-r requirements.txt (line 3)) (3.6.5)
# Requirement already satisfied: joblib in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from nltk>=3.1->textblob->-r requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: click in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from nltk>=3.1->textblob->-r requirements.txt (line 3)) (8.0.3)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: tomli>=1.0.0 in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib->-r requirements.txt (line 1)) (1.2.2)
# Requirement already satisfied: setuptools in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib->-r requirements.txt (line 1)) (59.4.0)
# Requirement already satisfied: typing-extensions in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from torch>=1.0.0->pytorch-transformers->-r requirements.txt (line 2)) (3.7.4.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from boto3->pytorch-transformers->-r requirements.txt (line 2)) (0.10.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from boto3->pytorch-transformers->-r requirements.txt (line 2)) (0.5.0)
# Requirement already satisfied: botocore<1.24.0,>=1.23.21 in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from boto3->pytorch-transformers->-r requirements.txt (line 2)) (1.23.21)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from requests->pytorch-transformers->-r requirements.txt (line 2)) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from requests->pytorch-transformers->-r requirements.txt (line 2)) (2.0.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from requests->pytorch-transformers->-r requirements.txt (line 2)) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages (from requests->pytorch-transformers->-r requirements.txt (line 2)) (3.1)

# %% [markdown]
# ## Loading Crowdsourcing Dataset

# %% [markdown]
# - Data point: 287
# - Dev set: 50
# - Test set: 50

# %%
from data import load_data

crowd_labels, df_train, df_dev, df_test = load_data()

Y_dev = df_dev.sentiment.values
Y_test = df_test.sentiment.values

# %%
crowd_labels.head()
# Out:
#           worker_id  label
# tweet_id
# 82510997   18034918      1
# 82510997    7450342      1
# 82510997   18465660      1
# 82510997   17475684      0
# 82510997   14472526      1

# %%
df_train.head()
# Out:
#           tweet_id                                         tweet_text
# tweet_id
# 82838854  82838854  @mention nope. Never got a chance to head out....
# 83258131  83258131            Damn weather, just turn and stay sunny.
# 82512145  82512145  Hi from sunny Boston. Weather is fine, wish yo...
# 82511193  82511193                   Ughhhhhh its so damn hot outside
# 81179800  81179800  This week in NYC will mark the longest stretch...

# %%
df_dev.head()
# Out:
#           tweet_id                                         tweet_text  \
# tweet_id
# 79197834  79197834                  @mention not in sunny dover! haha
# 80059939  80059939  It is literally pissing it down in sideways ra...
# 79196441  79196441  Dear perfect weather, thanks for the vest lunc...
# 84047300  84047300  RT @mention: I can't wait for the storm tonigh...
# 83255121  83255121  60 degrees. And its almost the end of may. Wis...
#
#           sentiment
# tweet_id
# 79197834          1
# 80059939          0
# 79196441          1
# 84047300          1
# 83255121          0

# %%
df_test.head()
# Out:
#           tweet_id                                         tweet_text  \
# tweet_id
# 82850069  82850069  RT @mention: Life is so much more manageable w...
# 81995718  81995718                 @mention  Sunshine! You lucky dog!
# 80058872  80058872              It is hot out here but it feels great
# 84313204  84313204  - this house is beyond cold..feels like imm la...
# 81996499  81996499  damn its goin rain all next week -.- where the...
#
#           sentiment
# tweet_id
# 82850069          1
# 81995718          1
# 80058872          1
# 84313204          0
# 81996499          0

# %% [markdown]
# ## Writing Labeling Functions

# %% [markdown]
# Each crowdworkers can be thought of as a single labeling function, as each worker labels a subset of data points, and may have errors or conflicting labels with other workers / labeling functions. So we create one labeling function per worker. We'll simply return the label the worker submitted for a given tweet, and abstain if they didn't submit a label for it.

# %% [markdown]
# ### Crowdworker labeling functions

# %%
labels_by_annotator = crowd_labels.groupby("worker_id")

worker_dicts = {}
for worker_id in labels_by_annotator.groups:
  worker_df = labels_by_annotator.get_group(worker_id)[["label"]]
  worker_dicts[worker_id] = dict(zip(worker_df.index, worker_df.label))

print("Number of workers", len(worker_dicts))
# Out:
# Number of workers 100

# %%
from snorkel.labeling import LabelingFunction

ABSTAIN = -1

def worker_lf(x, worker_dict):
  return worker_dict.get(x.tweet_id, ABSTAIN)

def make_worker_lf(worker_id):
  worker_dict = worker_dicts[worker_id]
  name = f"worker_{worker_id}"
  return LabelingFunction(name, f=worker_lf, resources={"worker_dict": worker_dict})

worker_lfs = [make_worker_lf(worker_id) for worker_id in worker_dicts]

# %%
from snorkel.labeling import PandasLFApplier

applier = PandasLFApplier(lfs=worker_lfs)

L_train = applier.apply(df_train)

L_dev = applier.apply(df_dev)
# Out:
# 100%|████████████████████████████████████████████████████████████████████| 187/187 [00:00<00:00, 2928.92it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 2981.32it/s]

# %%
from snorkel.labeling import LFAnalysis

LFAnalysis(L_dev, worker_lfs).lf_summary(Y_dev).sample(5)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
#                   j Polarity  Coverage  Overlaps  Conflicts  Correct  \
# worker_14472526  47   [0, 1]      0.12      0.12       0.12        5
# worker_6498214   12      [1]      0.02      0.02       0.02        0
# worker_8449724   20      [1]      0.06      0.06       0.04        3
# worker_18500901  81   [0, 1]      0.04      0.04       0.04        2
# worker_15549817  54       []      0.00      0.00       0.00        0
#
#                  Incorrect  Emp. Acc.
# worker_14472526          1   0.833333
# worker_6498214           1   0.000000
# worker_8449724           0   1.000000
# worker_18500901          0   1.000000
# worker_15549817          0   0.000000

# %%
print(f"Training set coverage: {100 * LFAnalysis(L_train).label_coverage(): 0.1f}%")
print(f"Dev set coverage: {100 * LFAnalysis(L_dev).label_coverage(): 0.1f}%")
# Out:
# Training set coverage:  50.3%
# Dev set coverage:  50.0%

# %%
from snorkel.labeling import labeling_function
from snorkel.preprocess import preprocessor
from textblob import TextBlob

POSITIVE = 1
NEGATIVE = 0

@preprocessor(memoize=True)
def textblob_polarity(x):
  scores = TextBlob(x.tweet_text)
  x.polarity = scores.polarity
  return x

@labeling_function(pre=[textblob_polarity])
def polarity_positive(x):
  return POSITIVE if x.polarity > 0.3 else ABSTAIN

@labeling_function(pre=[textblob_polarity])
def polarity_negative(x):
  return NEGATIVE if x.polarity < -0.25 else ABSTAIN

@labeling_function(pre=[textblob_polarity])
def polarity_negative_2(x):
  return NEGATIVE if x.polarity <= 0.3 else ABSTAIN

# %%
text_lfs = [
  polarity_positive,
  polarity_negative,
  polarity_negative_2
]

lfs = text_lfs + worker_lfs

applier = PandasLFApplier(lfs=lfs)
L_train = applier.apply(df_train)
L_dev = applier.apply(df_dev)
# Out:
# 100%|████████████████████████████████████████████████████████████████████| 187/187 [00:00<00:00, 1383.81it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1467.96it/s]

# %%
LFAnalysis(L_dev, lfs=lfs).lf_summary(Y_dev).head()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# /opt/homebrew/Caskroom/miniforge/base/envs/snorkel/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
#                      j Polarity  Coverage  Overlaps  Conflicts  Correct  \
# polarity_positive    0      [1]      0.30      0.16       0.12       15
# polarity_negative    1      [0]      0.10      0.10       0.04        5
# polarity_negative_2  2      [0]      0.70      0.40       0.32       26
# worker_6332651       3   [0, 1]      0.06      0.06       0.06        1
# worker_6336109       4       []      0.00      0.00       0.00        0
#
#                      Incorrect  Emp. Acc.
# polarity_positive            0   1.000000
# polarity_negative            0   1.000000
# polarity_negative_2          9   0.742857
# worker_6332651               2   0.333333
# worker_6336109               0   0.000000

# %%
print(f"Training set coverage: {100 * LFAnalysis(L_train).label_coverage(): 0.1f}%")
print(f"Dev set coverage: {100 * LFAnalysis(L_dev).label_coverage(): 0.1f}%")
# Out:
# Training set coverage:  100.0%
# Dev set coverage:  100.0%

# %% [markdown]
# ## Train LabelModel and Generate Probabilistic Labels

# %%
from snorkel.labeling.model import LabelModel

# Train LabelModel
label_model = LabelModel(cardinality=2, verbose=True)
label_model.fit(L_train=L_train, n_epochs=100, seed=123, log_freq=20, l2=0.1, lr=0.01)
# Out:
# INFO:root:Computing O...
# INFO:root:Estimating \mu...
#   0%|                                                                             | 0/100 [00:00<?, ?epoch/s]INFO:root:[0 epochs]: TRAIN:[loss=2.494]
# INFO:root:[20 epochs]: TRAIN:[loss=0.635]
# INFO:root:[40 epochs]: TRAIN:[loss=0.605]
#  46%|██████████████████████████████▊                                    | 46/100 [00:00<00:00, 455.57epoch/s]INFO:root:[60 epochs]: TRAIN:[loss=0.590]
# INFO:root:[80 epochs]: TRAIN:[loss=0.592]
# 100%|██████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 407.92epoch/s]
# INFO:root:Finished Training

# %%
from snorkel.analysis import metric_score

preds_dev = label_model.predict(L_dev)

acc = metric_score(Y_dev, preds_dev, probs=None, metric="accuracy")

print(f"LabelModel Accuracy: {acc:.3f}")
# Out:
# LabelModel Accuracy: 0.920

# %% [markdown]
# The model got very high accuracy on the development set, This is due to the abundance of high quality crowdworker labels. **Since we don't have these high quality crowdsourcing labels for the test set or new incoming data points, we can't use the LabelMdoel reliably at inference time**. In order to run inference on new incoming data points, we need to train a discriminative model over the tweets themselves.

# %%
preds_train = label_model.predict(L_train)

# %% [markdown]
# ## Use Soft Labels to Train End Model

# %% [markdown]
# ### Getting features from BERT

# %%
import numpy as np
import torch
from pytorch_transformers import BertModel, BertTokenizer

model = BertModel.from_pretrained("bert-base-uncased")
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
# Out:
# INFO:pytorch_transformers.modeling_utils:loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /Users/scottchu/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# INFO:pytorch_transformers.modeling_utils:Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "pad_token_id": 0,
#   "pruned_heads": {},
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "vocab_size": 30522
# }
#
# INFO:pytorch_transformers.modeling_utils:loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin from cache at /Users/scottchu/.cache/torch/pytorch_transformers/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# INFO:pytorch_transformers.tokenization_utils:loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /Users/scottchu/.cache/torch/pytorch_transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084

# %%
def encode_text(text):
  input_ids = torch.tensor([tokenizer.encode(text)])
  return model(input_ids)[0].mean(1)[0].detach().numpy()

# %%
X_train = np.array(list(df_train.tweet_text.apply(encode_text).values))
X_test = np.array(list(df_test.tweet_text.apply(encode_text).values))

# %% [markdown]
# ### Model on labels

# %%
from sklearn.linear_model import LogisticRegression

sklearn_model = LogisticRegression(solver="liblinear")
sklearn_model.fit(X_train, preds_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
print(f"Accuracy of trained model: {sklearn_model.score(X_test, Y_test)}")
# Out:
# Accuracy of trained model: 0.86

# %% [markdown]
# ## Further Readings
# - [BERT](https://github.com/google-research/bert)
