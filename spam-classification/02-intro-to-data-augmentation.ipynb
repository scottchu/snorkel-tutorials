# %% [markdown]
# # Snorkel Intro Tutorial: Data Augmentation
# Data augmentation is a popular technique for increasing the size of labeled training sets by applying **class-preserving** transformations to create copies of labeled data points.
#
# In the image domain, it is crucial factor in almost every state-of-art result today and is quickly gaining popularity in text-based applications.
#
# Snorkel models the data augmentation process by applying user-defined **transformation functions (TFs)** in sequence.

# %% [markdown]
# ## Preparation

# %%
import os
import random

import numpy as np
import pandas as pd
import tensorflow as tf

# %%
if os.path.basename(os.getcwd()) == "snorkel-tutorials":
  os.chdir("./spam-classification")

print(os.getcwd())
# Out:
# /Users/scottchu/Projects/learning/snorkel-tutorials/spam-classification

# %%
# !pip install -r requirements.txt -q

# %%
# Turn off TensorFlow logging messages
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

# %%
# For reproducibility
seed = 0
os.environ["PYTHONHASHSEED"] = str(seed)
np.random.seed(0)
random.seed(0)

# %%
DISPLAY_ALL_TEXT = False

pd.set_option("display.max_colwidth", 0 if DISPLAY_ALL_TEXT else 50)

# %%
# Download the spaCy english model
! python -m spacy download en_core_web_sm -q
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# ## 1. Loading Data

# %%
from utils import load_spam_dataset

df_train, df_test = load_spam_dataset(load_train_labels=True)

Y_train = df_train["label"].values
Y_test = df_train["label"].values

# %%
df_train.head()
# Out:
#              author                 date  \
# 0  Alessandro leite  2014-11-05T22:21:36
# 1      Salim Tayara  2014-11-02T14:33:30
# 2           Phuc Ly  2014-01-20T15:27:47
# 3      DropShotSk8r  2014-01-19T04:27:18
# 4            css403  2014-11-07T14:25:48
#
#                                                 text  label  video
# 0  pls http://www10.vakinha.com.br/VaquinhaE.aspx...      1      1
# 1  if your like drones, plz subscribe to Kamal Ta...      1      1
# 2                     go here to check the views :3﻿      0      1
# 3            Came here to check the views, goodbye.﻿      0      1
# 4                      i am 2,126,492,636 viewer :D﻿      0      1

# %% [markdown]
# ## 2. Writing Transformation Functions

# %% [markdown]
# Transformation functions are functions that can be applied to a training data point to create another valid training data point of the same class.
#
# For example, for image classification problems, it is common to **rotate** or **crop** images in the training data to create new training inputs.
#
# Transformation functions should be **atomic** (a small rotation of an image, or changing a single word in a sentence). We then compose multiple transformation functions when applying them to training data points.

# %%
from snorkel.preprocess.nlp import SpacyPreprocessor

spacy = SpacyPreprocessor(text_field="text", doc_field="doc", memoize=True)

# %%
import names
from snorkel.augmentation import transformation_function

# Pregenerate some random person names to replace existing ones with
# for the transformation strategies below
replacement_names = [names.get_full_name() for _ in range(50)]

# %%
from utils import preview_tf

# %%
@transformation_function(pre=[spacy])
def change_person(x):
  person_names = [ent.text for ent in x.doc.ents if ent.label_ == "PERSON"]
  # If there is at least one person name, replace a random one. Else return None.
  if person_names:
    name_to_replace = np.random.choice(person_names)
    replacement_name = np.random.choice(replacement_names)
    x.text = x.text.replace(name_to_replace, replacement_name)
    return x

preview_tf(df_train, change_person, 20)
# Out:
#           TF Name                                      Original Text  \
# 0   change_person  "eye of the tiger" "i am the champion" seems l...
# 1   change_person  Οh my god ... Roar is the most liked video at ...
# 2   change_person  I started hating Katy Perry after finding out ...
# 3   change_person  i rekt ur mum last nite. cuz da haterz were 2 ...
# 4   change_person  share and like this page to win a hand signed ...
# 5   change_person  WHATS UP EVERYONE!? :-) I Trying To Showcase M...
# 6   change_person  ••••►►My name is George and let me tell u EMIN...
# 7   change_person  The first billion viewed this because they tho...
# 8   change_person  You guys should check out this EXTRAORDINARY w...
# 9   change_person              i love Rihanna 😍😍😍😍[♧from Thailand♧]﻿
# 10  change_person  http://www.guardalo.org/best-of-funny-cats-gat...
# 11  change_person           Still a very fun music video to watch! ﻿
# 12  change_person  Check out this video on YouTube: <a href="http...
# 13  change_person  This song is so AWESOME!!!She made everything ...
# 14  change_person  Look at the pictures, if not difficult http://...
# 15  change_person  You guys should check out this EXTRAORDINARY w...
# 16  change_person                         Plizz withing my channel ﻿
# 17  change_person  The boyfriend was Charlie from the TV show LOST ﻿
# 18  change_person                                       Very Nice !﻿
# 19  change_person  Katy Perry's songs are the best of the songs o...
#
#                                      Transformed Text
# 0   "eye of the tiger" "i am the champion" seems l...
# 1   Οh my god ... Roar is the most liked video at ...
# 2   I started hating Douglas Schmidt after finding...
# 3   i rekt ur mum last nite. cuz da haterz were 2 ...
# 4   share and like this page to win a hand signed ...
# 5   WHATS UP EVERYONE!? :-) I Trying To Showcase M...
# 6   ••••►►My name is George and let me tell u EMIN...
# 7   The first billion viewed this because they tho...
# 8   You guys should check out this EXTRAORDINARY w...
# 9         i love Malcolm Lafoe 😍😍😍😍[♧from Thailand♧]﻿
# 10  http://www.guardalo.org/best-of-funny-cats-gat...
# 11  Still a very fun music video to watch! Brenda ...
# 12  Check out this video on YouTube: <a href="http...
# 13  This song is so AWESOME!!!She made everything ...
# 14  Look at the pictures, if not difficult http://...
# 15  You guys should check out this EXTRAORDINARY w...
# 16             Plizz withing my channel Malcolm Lafoe
# 17  The boyfriend was Terry Sease from the TV show...
# 18                          Very Nice !James Williams
# 19  Nikki Dwyer songs are the best of the songs of...

# %%
@transformation_function(pre=[spacy])
def swap_adjectives(x):
  adjective_idxs = [i for i, token in enumerate(x.doc) if token.pos_ == "ADJ"]
  # Check that there are at least two adjectives to swap.
  if len(adjective_idxs) >= 2:
    idx1, idx2 = sorted(np.random.choice(adjective_idxs, 2, replace=False))
    # Swap tokens in positions idx1 and idx2.
    x.text = " ".join(
      [
        x.doc[:idx1].text,
        x.doc[idx2].text,
        x.doc[1 + idx1 : idx2].text,
        x.doc[idx1].text,
        x.doc[1 + idx2 :].text,
      ]
    )
    return x

preview_tf(df_train, swap_adjectives, 20)
# Out:
#             TF Name                                      Original Text  \
# 0   swap_adjectives  hey guys look im aware im spamming and it piss...
# 1   swap_adjectives  I started hating Katy Perry after finding out ...
# 2   swap_adjectives  i rekt ur mum last nite. cuz da haterz were 2 ...
# 3   swap_adjectives  You gotta say its funny. well not 2 billion wo...
# 4   swap_adjectives  Hello! Do you like gaming, art videos, scienti...
# 5   swap_adjectives  Haha its so funny to see the salt of westerner...
# 6   swap_adjectives  Why does this video have so many views? Becaus...
# 7   swap_adjectives  Please help me give my son a grave.  http://ww...
# 8   swap_adjectives  ••••►►My name is George and let me tell u EMIN...
# 9   swap_adjectives  Hey I think I know what where dealing with her...
# 10  swap_adjectives  The first billion viewed this because they tho...
# 11  swap_adjectives  Come check out our music channel! go check out...
# 12  swap_adjectives  this fucking song like a&#39;n oreo the only w...
# 13  swap_adjectives  3 yrs ago I had a health scare but thankfully ...
# 14  swap_adjectives  Lil m !!!!! Check hi out!!!!! Does live the wa...
# 15  swap_adjectives  Hey! I'm NERDY PEACH and I'm a new youtuber an...
# 16  swap_adjectives  You guys should check out this EXTRAORDINARY w...
# 17  swap_adjectives   i like this song the video goes perfect with it﻿
# 18  swap_adjectives  We are an EDM apparel company dedicated to bri...
# 19  swap_adjectives  You guys should check out this EXTRAORDINARY w...
#
#                                      Transformed Text
# 0   hey guys look im more im spamming and it pisse...
# 1   I started hating Katy Perry after finding out ...
# 2   i rekt ur mum sponswer nite. cuz da haterz wer...
# 3   You gotta say its funny. well not 2 billion wo...
# 4   Hello! Do you like gaming, art videos, scienti...
# 5   Haha its so top to see the salt of westerners ...
# 6   Why does this video have so many views? Becaus...
# 7   Please help me give my son a grave.   anymore....
# 8   ••••►►My name is George and let me tell u EMIN...
# 9   Hey I think I know what where dealing with her...
# 10  The first billion viewed this because they tho...
# 11  Come check out our music channel! go check out...
# 12  this fucking song like a&#39;n oreo the white ...
# 13  3 yrs ago I had a health scare but thankfully ...
# 14  Lil m !!!!! Check hi out!!!!! Does live the wa...
# 15  Hey! I'm NERDY PEACH and I'm a lt;3 youtuber a...
# 16  You guys should check out this EXTRAORDINARY w...
# 17  i like this song the video goes it﻿ with perfect
# 18  We are an EDM apparel company dedicated to bri...
# 19  You guys should check out this EXTRAORDINARY w...

# %%
import nltk
from nltk.corpus import wordnet as wn

nltk.download("wordnet")

def get_synonym(word, pos=None):
  """Get synonym for word given its part-of-speech (pos)."""
  synsets = wn.synsets(word, pos=pos)
  # Return None if wordnet has no synsets (synonym sets) for this word and pos.
  if synsets:
    words = [lemma.name() for lemma in synsets[0].lemmas()]
    if words[0].lower() != word.lower():  # Skip if synonym is same as word.
      # Multi word synonyms in wordnet use '_' as a separator e.g. reckon_with. Replace it with space.
      return words[0].replace("_", " ")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/scottchu/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def replace_token(spacy_doc, idx, replacement):
  """Replace token in position idx with replacement."""
  return " ".join([
    spacy_doc[:idx].text, 
    replacement, 
    spacy_doc[1 + idx :].text
  ])

# %%
@transformation_function(pre=[spacy])
def replace_verb_with_synonym(x):
  # Get indices of verb tokens in sentence.
  verb_idxs = [i for i, token in enumerate(x.doc) if token.pos_ == "VERB"]
  if verb_idxs:
    # Pick random verb idx to replace.
    idx = np.random.choice(verb_idxs)
    synonym = get_synonym(x.doc[idx].text, pos="v")
    # If there's a valid verb synonym, replace it. Otherwise, return None.
    if synonym:
      x.text = replace_token(x.doc, idx, synonym)
      return x

preview_tf(df_train, replace_verb_with_synonym, 20)
# Out:
#                       TF Name  \
# 0   replace_verb_with_synonym
# 1   replace_verb_with_synonym
# 2   replace_verb_with_synonym
# 3   replace_verb_with_synonym
# 4   replace_verb_with_synonym
# 5   replace_verb_with_synonym
# 6   replace_verb_with_synonym
# 7   replace_verb_with_synonym
# 8   replace_verb_with_synonym
# 9   replace_verb_with_synonym
# 10  replace_verb_with_synonym
# 11  replace_verb_with_synonym
# 12  replace_verb_with_synonym
# 13  replace_verb_with_synonym
# 14  replace_verb_with_synonym
# 15  replace_verb_with_synonym
# 16  replace_verb_with_synonym
# 17  replace_verb_with_synonym
# 18  replace_verb_with_synonym
# 19  replace_verb_with_synonym
#
#                                         Original Text  \
# 0   "eye of the tiger" "i am the champion" seems l...
# 1   Οh my god ... Roar is the most liked video at ...
# 2   I started hating Katy Perry after finding out ...
# 3   This video is so racist!!! There are only anim...
# 4   You gotta say its funny. well not 2 billion wo...
# 5   reminds me of this song https://soundcloud.com...
# 6                           2 billion....Coming soon﻿
# 7   ••••►►My name is George and let me tell u EMIN...
# 8   Hey I think I know what where dealing with her...
# 9   Almost 1 Bil. What? Wow, GS sucks, in my opini...
# 10  The first billion viewed this because they tho...
# 11  Come check out our music channel! go check out...
# 12  if i reach 100 subscribers i will go round in ...
# 13                      LOL this shit never gets old﻿
# 14  OH SHIT THIS WAS UPLOADED ON MY BIRTHDAY, fina...
# 15  I cried this song bringing back some hard memo...
# 16  Wow this video almost has a billion views! Did...
# 17  3 yrs ago I had a health scare but thankfully ...
# 18  Lil m !!!!! Check hi out!!!!! Does live the wa...
# 19  OMG 2/7 People watched this video because ther...
#
#                                      Transformed Text
# 0   "eye of the tiger" "i am the champion" seems l...
# 1   Οh my god ... Roar is the most wish video at V...
# 2   I started hating Katy Perry after finding out ...
# 3   This video is so racist!!! There be only anima...
# 4   You gotta say its funny. well not 2 billion wo...
# 5    remind me of this song https://soundcloud.com...
# 6                            2 billion.... come soon﻿
# 7   ••••►►My name is George and let me tell u EMIN...
# 8   Hey I think I know what where dealing with her...
# 9   Almost 1 Bil. What? Wow, GS suck , in my opini...
# 10  The first billion see this because they though...
# 11  Come check out our music channel! go check out...
# 12  if i reach 100 subscribers i will go round in ...
# 13                       LOL this shit never get old﻿
# 14  OH SHIT THIS WAS upload ON MY BIRTHDAY, finall...
# 15   I cried this song bring back some hard memories﻿
# 16  Wow this video almost have a billion views! Di...
# 17  3 yrs ago I had a health scare but thankfully ...
# 18  Lil m !!!!! Check hi out!!!!! Does populate th...
# 19  OMG 2/7 People watched this video because ther...

# %%
@transformation_function(pre=[spacy])
def replace_noun_with_synonym(x):
    # Get indices of noun tokens in sentence.
  noun_idxs = [i for i, token in enumerate(x.doc) if token.pos_ == "NOUN"]
  if noun_idxs:
      # Pick random noun idx to replace.
    idx = np.random.choice(noun_idxs)
    synonym = get_synonym(x.doc[idx].text, pos="n")
    # If there's a valid noun synonym, replace it. Otherwise, return None.
    if synonym:
      x.text = replace_token(x.doc, idx, synonym)
      return x

preview_tf(df_train, replace_noun_with_synonym, 20)
# Out:
#                       TF Name  \
# 0   replace_noun_with_synonym
# 1   replace_noun_with_synonym
# 2   replace_noun_with_synonym
# 3   replace_noun_with_synonym
# 4   replace_noun_with_synonym
# 5   replace_noun_with_synonym
# 6   replace_noun_with_synonym
# 7   replace_noun_with_synonym
# 8   replace_noun_with_synonym
# 9   replace_noun_with_synonym
# 10  replace_noun_with_synonym
# 11  replace_noun_with_synonym
# 12  replace_noun_with_synonym
# 13  replace_noun_with_synonym
# 14  replace_noun_with_synonym
# 15  replace_noun_with_synonym
# 16  replace_noun_with_synonym
# 17  replace_noun_with_synonym
# 18  replace_noun_with_synonym
# 19  replace_noun_with_synonym
#
#                                         Original Text  \
# 0   "eye of the tiger" "i am the champion" seems l...
# 1   You gotta say its funny. well not 2 billion wo...
# 2   Hello! Do you like gaming, art videos, scienti...
# 3   Check out my Music Videos! and PLEASE SUBSCRIB...
# 4                  Love the way you lie - Driveshaft﻿
# 5                                 Watch my videos xx﻿
# 6   Why does this video have so many views? Becaus...
# 7   WHATS UP EVERYONE!? :-) I Trying To Showcase M...
# 8             Get free gift cards and pay pal money!﻿
# 9   The first billion viewed this because they tho...
# 10                    I could hear this for years ;3﻿
# 11  Lil m !!!!! Check hi out!!!!! Does live the wa...
# 12  OMG 2/7 People watched this video because ther...
# 13  Hey! I'm NERDY PEACH and I'm a new youtuber an...
# 14  We are an EDM apparel company dedicated to bri...
# 15  You guys should check out this EXTRAORDINARY w...
# 16  PLEASE DON&#39;T LIKE THIS COMMENT IF YOU ARE ...
# 17                                      Awsome<br />﻿
# 18         I love your songs eminem your the rap god﻿
# 19  You guys should check out this EXTRAORDINARY w...
#
#                                      Transformed Text
# 0   "eye of the tiger" "i am the champion" seems l...
# 1   You gotta say its funny. well not 2 billion wo...
# 2   Hello! Do you like gaming, art video , scienti...
# 3   Check out my Music Videos! and PLEASE SUBSCRIB...
# 4               Love the manner you lie - Driveshaft﻿
# 5                                  Watch my video xx﻿
# 6   Why does this video have so many views? Becaus...
# 7   WHATS UP EVERYONE!? :-) I Trying To Showcase M...
# 8         Get free gift card game and pay pal money!﻿
# 9   The first billion viewed this because they tho...
# 10                  I could hear this for old age ;3﻿
# 11  Lil m !!!!! Check hi out!!!!! Does live the ma...
# 12  OMG 2/7 People watched this video because ther...
# 13  Hey! I'm NERDY PEACH and I'm a new youtuber an...
# 14  We are an EDM apparel company dedicated to bri...
# 15  You guys should check out this EXTRAORDINARY w...
# 16  PLEASE DON&#39;T LIKE THIS remark IF YOU ARE W...
# 17                                Awsome< bromine />﻿
# 18          I love your song eminem your the rap god﻿
# 19  You guy should check out this EXTRAORDINARY we...

# %%
@transformation_function(pre=[spacy])
def replace_adjective_with_synonym(x):
    # Get indices of adjective tokens in sentence.
  adjective_idxs = [i for i, token in enumerate(x.doc) if token.pos_ == "ADJ"]
  if adjective_idxs:
    # Pick random adjective idx to replace.
    idx = np.random.choice(adjective_idxs)
    synonym = get_synonym(x.doc[idx].text, pos="a")
    # If there's a valid adjective synonym, replace it. Otherwise, return None.
    if synonym:
      x.text = replace_token(x.doc, idx, synonym)
      return x

preview_tf(df_train, replace_adjective_with_synonym, 20)
# Out:
#                            TF Name  \
# 0   replace_adjective_with_synonym
# 1   replace_adjective_with_synonym
# 2   replace_adjective_with_synonym
# 3   replace_adjective_with_synonym
# 4   replace_adjective_with_synonym
# 5   replace_adjective_with_synonym
# 6   replace_adjective_with_synonym
# 7   replace_adjective_with_synonym
# 8   replace_adjective_with_synonym
# 9   replace_adjective_with_synonym
# 10  replace_adjective_with_synonym
# 11  replace_adjective_with_synonym
# 12  replace_adjective_with_synonym
# 13  replace_adjective_with_synonym
# 14  replace_adjective_with_synonym
# 15  replace_adjective_with_synonym
# 16  replace_adjective_with_synonym
# 17  replace_adjective_with_synonym
# 18  replace_adjective_with_synonym
# 19  replace_adjective_with_synonym
#
#                                         Original Text  \
# 0   You gotta say its funny. well not 2 billion wo...
# 1   Haha its so funny to see the salt of westerner...
# 2   ••••►►My name is George and let me tell u EMIN...
# 3   Shuffling all the way with LMFAO! I like this ...
# 4   Hey guys plz check out my youtube channel to c...
# 5   I cried this song bringing back some hard memo...
# 6   You guys should check out this EXTRAORDINARY w...
# 7   You guys should check out this EXTRAORDINARY w...
# 8                          Super awesome video<br />﻿
# 9   Check out our vids, our songs are awesome! And...
# 10  You guys should check out this EXTRAORDINARY w...
# 11  Check out this funny video &quot;Cereal Box Kn...
# 12  Aye homies check out our remix to 50 Cent Your...
# 13  everyone please come check our newest song in ...
# 14  why are they 5million comments when there is o...
# 15              i am a big fan of you and i love you﻿
# 16  i hate this music. fucking singer and every ko...
# 17            I think he was drunk during this :) x)﻿
# 18                       Thumbs up if shrek is gay 👍﻿
# 19  Media is Evil! Please see and share: W W W. TH...
#
#                                      Transformed Text
# 0   You gotta say its funny. well not 2 billion wo...
# 1   Haha its so amusing to see the salt of western...
# 2   ••••►►My name is George and let me tell u EMIN...
# 3   Shuffling all the way with LMFAO! I like this ...
# 4   Hey guys plz check out my youtube channel to c...
# 5   I cried this song bringing back some difficult...
# 6   You guys should check out this EXTRAORDINARY w...
# 7   You guys should check out this EXTRAORDINARY w...
# 8                            ace awesome video<br />﻿
# 9   Check out our vids, our songs are amazing ! An...
# 10  You guys should check out this EXTRAORDINARY w...
# 11  Check out this amusing video &quot;Cereal Box ...
# 12  Aye homies check out our remix to 50 Cent Your...
# 13  everyone please come check our new song in mem...
# 14  why are they 5million comments when there is o...
# 15            i am a large fan of you and i love you﻿
# 16  i hate this music. bally singer and every koea...
# 17      I think he was intoxicated during this :) x)﻿
# 18                    Thumbs up if shrek is cheery 👍﻿
# 19  Media is Evil! Please see and share: W W W. TH...

# %%
tfs = [
  change_person,
  swap_adjectives,
  replace_verb_with_synonym,
  replace_noun_with_synonym,
  replace_adjective_with_synonym,
]

# %%
from utils import preview_tfs

preview_tfs(df_train, tfs)
# Out:
#                           TF Name  \
# 0                   change_person
# 1                 swap_adjectives
# 2       replace_verb_with_synonym
# 3       replace_noun_with_synonym
# 4  replace_adjective_with_synonym
#
#                                        Original Text  \
# 0  "eye of the tiger" "i am the champion" seems l...
# 1  hey guys look im aware im spamming and it piss...
# 2  "eye of the tiger" "i am the champion" seems l...
# 3  "eye of the tiger" "i am the champion" seems l...
# 4  You gotta say its funny. well not 2 billion wo...
#
#                                     Transformed Text
# 0  "eye of the tiger" "i am the champion" seems l...
# 1  hey guys look im aware im spamming and it piss...
# 2  "eye of the tiger" "i am the champion" look li...
# 3  "eye of the tiger" "i am the champion" seems l...
# 4  You gotta say its amusing . well not 2 billion...

# %% [markdown]
# The TFs are expected to be heuristic strategies that indeed preserve the class most of the time, but don't need to be perfect. It is especially true when using automated data augmentation techniques which can learn to avoid particularly corrupted data points.

# %% [markdown]
# ## 3. Applying Transformation Functions to Augment Our Dataset

# %%
from snorkel.augmentation import RandomPolicy

random_policy = RandomPolicy(
  len(tfs), 
  sequence_length=2, 
  n_per_original=2, 
  keep_original=True
)

# %%
from snorkel.augmentation import MeanFieldPolicy

mean_field_policy = MeanFieldPolicy(
  len(tfs),
  sequence_length=2,
  n_per_original=2,
  keep_original=True,
  p=[0.05, 0.05, 0.3, 0.3, 0.3]
)

# %%
from snorkel.augmentation import PandasTFApplier

tf_applier = PandasTFApplier(tfs, mean_field_policy)

df_train_augmented = tf_applier.apply(df_train)

Y_train_augmented = df_train_augmented["label"].values
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1586/1586 [00:29<00:00, 53.77it/s]

# %%
print(f"Original training set size: {len(df_train)}")
print(f"Augmented training set size: {len(df_train_augmented)}")
# Out:
# Original training set size: 1586
# Augmented training set size: 2429

# %%
df_train_augmented[["label", "text"]]
# Out:
#      label                                               text
# 0        1  pls http://www10.vakinha.com.br/VaquinhaE.aspx...
# 0        1  pls http://www10.vakinha.com.br/VaquinhaE.aspx...
# 0        1  pls http://www10.vakinha.com.br/VaquinhaE.aspx...
# 1        1  if your like drones, plz subscribe to Kamal Ta...
# 1        1  if your like drones, plz subscribe to Kamal Ta...
# ..     ...                                                ...
# 445      1  I hope everyone is in good spirits I&#39;m a h...
# 446      1  Lil m !!!!! Check hi out!!!!! Does live the wa...
# 446      1  Lil m !!!!! Check hi out!!!!! Does live the ma...
# 446      1  Lil m !!!!! Check hi out!!!!! Does live the ma...
# 447      1  Please check out my youtube channel! Just uplo...
#
# [2429 rows x 2 columns]

# %% [markdown]
# ## 4. Training a Model

# %%
import tensorflow as tf

session_conf = tf.compat.v1.ConfigProto(
  intra_op_parallelism_threads=1, 
  inter_op_parallelism_threads=1
)

tf.compat.v1.set_random_seed(0)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)
# Out:
# Metal device set to: Apple M1 Max
#
# systemMemory: 64.00 GB
# maxCacheSize: 21.33 GB
#
# WARNING:tensorflow:From /var/folders/l8/bf8ypysd7g91tsdjzrl_2sjr0000gn/T/ipykernel_21083/2601213079.py:10: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.

# %%
from utils import featurize_df_tokens

X_train = featurize_df_tokens(df_train)

X_train_augmented = featurize_df_tokens(df_train_augmented)

X_test = featurize_df_tokens(df_test)

# %%
def get_keras_lstm(num_buckets, embed_dim=16, rnn_state_size=64):
    lstm_model = tf.keras.Sequential()
    lstm_model.add(tf.keras.layers.Embedding(num_buckets, embed_dim))
    lstm_model.add(tf.keras.layers.LSTM(rnn_state_size, activation=tf.nn.relu))
    lstm_model.add(tf.keras.layers.Dense(1, activation=tf.nn.sigmoid))
    lstm_model.compile("Adagrad", "binary_crossentropy", metrics=["accuracy"])
    return lstm_model

# %%
def train_and_test(X_train, Y_train, X_test=X_test, Y_test=Y_test, num_buckets=30000):
  lstm_model = get_keras_lstm(num_buckets)
  lstm_model.fit(X_train, Y_train, epochs=5, verbose=0)
  preds_test = lstm_model.predict(X_test)[:, 0] > 0.5
  return (preds_test == Y_test).mean()

# %%
acc_augmented = train_and_test(X_train_augmented, Y_train_augmented)
acc_original = train_and_test(X_train, Y_train)

# %%
print(f"Test Accuracy (original training data): {100 * acc_original:.1f}%")
print(f"Test Accuracy (augmented training data): {100 * acc_augmented:.1f}%")

# %% [markdown]
# ## Further Reading
# - [Data Augmentation with Snorkel](https://www.snorkel.org/blog/tanda)
# - Keras LSTM (Long Short Term Memory)
# - TANDA Mean Field Model
